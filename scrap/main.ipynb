# %%
# Importar funciones comunes
import pandas as pd
from utils_common import obtener_sdapi_outlet_key

url_competicion = "https://www.scoresway.com/en_GB/soccer/liga-profesional-argentina-2025/3l4bzc8syz1ea2dnv453kp89g/fixtures"
# sdapi_outlet_key = obtener_sdapi_outlet_key(url_competicion)
#print(sdapi_outlet_key)

sdapi_outlet_key = 'ft1tiv1inq7v1sk3y9tv12yh5'
callback_id = 'W3e14cbc3e4b2577e854bf210e5a3c7028c7409678'

# %% [markdown]
# # COMPETICIONES

# %%
# # Opción 1: Usar las funciones de conveniencia (más fácil)
# from scraping_competitions import scrape_and_save_competitions, load_existing_competitions

# # Hacer scraping completo (obtener, guardar CSV y crear directorios)
# df_competitions, summary = scrape_and_save_competitions()

# # Ver resumen
# print(f"Total competiciones: {summary['total_competiciones']}")
# print(f"Competiciones por continente: {summary['competiciones_por_continente']}")

# # Cargar desde CSV existente
# df_competitions = load_existing_competitions()



# # Opción 2: Usar la clase directamente (más control)
# from scraping_competitions import CompetitionScraper

# scraper = CompetitionScraper()

# # Solo obtener datos (sin guardar)
# data = scraper.fetch_competitions_data()
# df = scraper.parse_competition_data(data)

# # Guardar por separado
# scraper.save_competitions_csv(df)
# scraper.create_directory_structure(df)

# %%
# En lugar de todo ese código, solo esto:
from scraping_competitions import scrape_and_save_competitions

df_competitions, summary = scrape_and_save_competitions()
display(df_competitions.head())
# Out:
# Obteniendo datos de competiciones...
# ✅ Datos obtenidos exitosamente
# ✅ Parseados 2172 competiciones
# ✅ Competiciones guardadas en: data/competiciones.csv
# ✅ Estructura de directorios creada exitosamente
#    - Directorios creados: 20
#    - Total competiciones procesadas: 2172
#   continente pais               competicion             id_competicion  \
# 0       Asia  AFC             AFC Asian Cup  93i7thp7zi0ympyt6l8aa1r2i
# 1       Asia  AFC   Asian Cup Qualification  emy1ibc8fu2l0fukh4vlu5xl5
# 2       Asia  AFC  AFC World Cup Qualifiers  40yjcbx2sq6oq736iqqqczwt1
# 3       Asia  AFC               Asian Games  8c93rclta164ypkno054nkfyt
# 4       Asia  AFC        ASEAN Championship  8dxsd8xnjm9n1ogo37yomgl3p
#
#                                                  url  \
# 0  https://www.scoresway.com/en_GB/soccer/afc-asi...
# 1  https://www.scoresway.com/en_GB/soccer/asian-c...
# 2  https://www.scoresway.com/en_GB/soccer/afc-wor...
# 3  https://www.scoresway.com/en_GB/soccer/asian-g...
# 4  https://www.scoresway.com/en_GB/soccer/asean-c...
#
#                                             crest    top  orden
# 0  https://www.scoresway.com/images/flags/afc.png  False     10
# 1  https://www.scoresway.com/images/flags/afc.png  False     15
# 2  https://www.scoresway.com/images/flags/afc.png  False     20
# 3  https://www.scoresway.com/images/flags/afc.png  False     30
# 4  https://www.scoresway.com/images/flags/afc.png  False     40

# %%
from scraping_competitions import load_existing_competitions
df_competitions = load_existing_competitions()
# Out:
# ✅ Competiciones cargadas desde: data/competiciones.csv

# %%
df_competitions
# Out:
#      continente  pais                          competicion  \
# 0          Asia   AFC                        AFC Asian Cup
# 1          Asia   AFC              Asian Cup Qualification
# 2          Asia   AFC             AFC World Cup Qualifiers
# 3          Asia   AFC                          Asian Games
# 4          Asia   AFC                   ASEAN Championship
# ...         ...   ...                                  ...
# 2167      World  FIFA                    ICC Futures Girls
# 2168      World  FIFA      Other Competition Matches Women
# 2169      World  FIFA  Women's International Champions Cup
# 2170      World  FIFA                 Yongchuan Tournament
# 2171      World  FIFA                Youth Club Friendlies
#
#                  id_competicion  \
# 0     93i7thp7zi0ympyt6l8aa1r2i
# 1     emy1ibc8fu2l0fukh4vlu5xl5
# 2     40yjcbx2sq6oq736iqqqczwt1
# 3     8c93rclta164ypkno054nkfyt
# 4     8dxsd8xnjm9n1ogo37yomgl3p
# ...                         ...
# 2167  an14w7aj2mfyjezi8ffyzz8tm
# 2168  dgyis04e8a4r2yx14z4r9cjx1
# 2169  ethi4xj3u6mzx1mpi7xq4ubmy
# 2170  f1r379mu8rr23p1c1a7ay16qy
# 2171  13g6xmizt8b2iq5zkdiiepu9m
#
#                                                     url  \
# 0     https://www.scoresway.com/en_GB/soccer/afc-asi...
# 1     https://www.scoresway.com/en_GB/soccer/asian-c...
# 2     https://www.scoresway.com/en_GB/soccer/afc-wor...
# 3     https://www.scoresway.com/en_GB/soccer/asian-g...
# 4     https://www.scoresway.com/en_GB/soccer/asean-c...
# ...                                                 ...
# 2167  https://www.scoresway.com/en_GB/soccer/icc-fut...
# 2168  https://www.scoresway.com/en_GB/soccer/other-c...
# 2169  https://www.scoresway.com/en_GB/soccer/women-s...
# 2170  https://www.scoresway.com/en_GB/soccer/yongchu...
# 2171  https://www.scoresway.com/en_GB/soccer/youth-c...
#
#                                                 crest    top  orden
# 0      https://www.scoresway.com/images/flags/afc.png  False     10
# 1      https://www.scoresway.com/images/flags/afc.png  False     15
# 2      https://www.scoresway.com/images/flags/afc.png  False     20
# 3      https://www.scoresway.com/images/flags/afc.png  False     30
# 4      https://www.scoresway.com/images/flags/afc.png  False     40
# ...                                               ...    ...    ...
# 2167  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2168  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2169  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2170  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2171  https://www.scoresway.com/images/flags/fifa.png  False   1000
#
# [2172 rows x 8 columns]

# %%
df_competitions=df_competitions[df_competitions['competicion']=='FIFA U20 World Cup']

# %%
from scraping_competitions import load_existing_competitions

df_competitions = load_existing_competitions()
total_competition = len(df_competitions)
total_competition
# Out:
# ✅ Competiciones cargadas desde: data/competiciones.csv
# 2172

# %%
df_competitions
# Out:
#      continente  pais                          competicion  \
# 0          Asia   AFC                        AFC Asian Cup
# 1          Asia   AFC              Asian Cup Qualification
# 2          Asia   AFC             AFC World Cup Qualifiers
# 3          Asia   AFC                          Asian Games
# 4          Asia   AFC                   ASEAN Championship
# ...         ...   ...                                  ...
# 2167      World  FIFA                    ICC Futures Girls
# 2168      World  FIFA      Other Competition Matches Women
# 2169      World  FIFA  Women's International Champions Cup
# 2170      World  FIFA                 Yongchuan Tournament
# 2171      World  FIFA                Youth Club Friendlies
#
#                  id_competicion  \
# 0     93i7thp7zi0ympyt6l8aa1r2i
# 1     emy1ibc8fu2l0fukh4vlu5xl5
# 2     40yjcbx2sq6oq736iqqqczwt1
# 3     8c93rclta164ypkno054nkfyt
# 4     8dxsd8xnjm9n1ogo37yomgl3p
# ...                         ...
# 2167  an14w7aj2mfyjezi8ffyzz8tm
# 2168  dgyis04e8a4r2yx14z4r9cjx1
# 2169  ethi4xj3u6mzx1mpi7xq4ubmy
# 2170  f1r379mu8rr23p1c1a7ay16qy
# 2171  13g6xmizt8b2iq5zkdiiepu9m
#
#                                                     url  \
# 0     https://www.scoresway.com/en_GB/soccer/afc-asi...
# 1     https://www.scoresway.com/en_GB/soccer/asian-c...
# 2     https://www.scoresway.com/en_GB/soccer/afc-wor...
# 3     https://www.scoresway.com/en_GB/soccer/asian-g...
# 4     https://www.scoresway.com/en_GB/soccer/asean-c...
# ...                                                 ...
# 2167  https://www.scoresway.com/en_GB/soccer/icc-fut...
# 2168  https://www.scoresway.com/en_GB/soccer/other-c...
# 2169  https://www.scoresway.com/en_GB/soccer/women-s...
# 2170  https://www.scoresway.com/en_GB/soccer/yongchu...
# 2171  https://www.scoresway.com/en_GB/soccer/youth-c...
#
#                                                 crest    top  orden
# 0      https://www.scoresway.com/images/flags/afc.png  False     10
# 1      https://www.scoresway.com/images/flags/afc.png  False     15
# 2      https://www.scoresway.com/images/flags/afc.png  False     20
# 3      https://www.scoresway.com/images/flags/afc.png  False     30
# 4      https://www.scoresway.com/images/flags/afc.png  False     40
# ...                                               ...    ...    ...
# 2167  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2168  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2169  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2170  https://www.scoresway.com/images/flags/fifa.png  False   1000
# 2171  https://www.scoresway.com/images/flags/fifa.png  False   1000
#
# [2172 rows x 8 columns]

# %% [markdown]
# # TEMPORADAS

# %%
# # Para empezar de cero:
# from scraping_seasons import smart_scrape_seasons

# # Empezar limpio (borra datos anteriores)
# df_seasons, summary = smart_scrape_seasons(
#     restart_from_zero=True,
#     batch_size=100  # Procesar 100 competiciones
# )

# print(f"✅ Procesadas {summary['total_temporadas']} temporadas")
# print(f"📈 Progreso: {summary['progress']['percentage']:.1f}%")

# # Para continuar automáticamente (si se corta):
# from scraping_seasons import smart_scrape_seasons

# # Detecta automáticamente desde dónde continuar
# df_seasons, summary = smart_scrape_seasons(
#     restart_from_zero=False,  # No borrar datos existentes
#     batch_size=100           # Procesar otros 100
# )

# print(f"✅ Total temporadas: {summary['total_temporadas']}")
# print(f"📈 Progreso: {summary['progress']['percentage']:.1f}%")

# %% [markdown]
# ## TEMPORADAS

# %%
from scraping_competitions import load_existing_competitions

df_competitions = load_existing_competitions()

total_competition = len(df_competitions)
total_competition
# Out:
# ✅ Competiciones cargadas desde: data/competiciones.csv
# 2157

# %%
# EJECUTAR CUANDO SE NECESITE TRAER NUEVAS SEASON SI NO NO PORQUE TARDA UNAS DOS HORAS
from scraping_seasons import smart_scrape_seasons

df_seasons, summary = smart_scrape_seasons(
    restart_from_zero=False, # True para empezar de cero, False para continuar
    batch_size=total_competition # Procesar todas las competiciones
    # batch_size=100 # Procesar 100 competiciones
)

# %%
print(f"✅ Procesadas {summary['total_temporadas']} temporadas")
print(f"✅ Procesadas {summary['competiciones_unicas']} competiciones")
print(f"✅ Procesadas {summary['paises_unicos']} paises unicos")
print(f"✅ Procesadas {summary['continentes_unicos']} continentes unicos")
# Out:
# ✅ Procesadas 0 temporadas
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 print(f"✅ Procesadas {summary['total_temporadas']} temporadas")
# ----> 2 print(f"✅ Procesadas {summary['competiciones_unicas']} competiciones")
#       3 print(f"✅ Procesadas {summary['paises_unicos']} paises unicos")
#       4 print(f"✅ Procesadas {summary['continentes_unicos']} continentes unicos")
#
# KeyError: 'competiciones_unicas'

# %%
df_seasons
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # FIXTURE

# %%
# # 1. Para empezar de cero:
# from scraping_seasons import load_existing_seasons
# from scraping_fixtures import smart_download_fixtures

# df_seasons = load_existing_seasons()

# # Borra fixtures existentes de Argentina y empieza limpio
# stats = smart_download_fixtures(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=True,  # 🔥 Borra y empieza de cero
#     batch_size=100          # Procesar 100 temporadas
# )

# print(f"✅ Descargadas {stats['success']} fixtures")
# print(f"📈 Progreso: {stats['progress']['percentage']:.1f}%")

# #########################################################

# #2. Para continuar automáticamente (si se corta):
# from scraping_fixtures import resume_fixtures_download

# # Detecta automáticamente desde dónde continuar
# stats = resume_fixtures_download(
#     df_seasons,
#     pais='Argentina',
#     batch_size=100
# )

# print(f"📈 Progreso: {stats['progress']['percentage']:.1f}%")

# #########################################################

# #3. Control total (la más versátil):
# from scraping_fixtures import smart_download_fixtures

# # Continuar desde donde se quedó
# stats = smart_download_fixtures(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=False,  # No borrar existentes
#     batch_size=150           # Procesar 150 más
# )

# # O empezar de cero solo para Sudamérica
# stats = smart_download_fixtures(
#     df_seasons,
#     continente='South America',
#     restart_from_zero=True,
#     batch_size=200
# )

# ##############################################################


# # 1. CASO MÁS COMÚN: Solo Argentina
# from scraping_seasons import load_existing_seasons
# from scraping_fixtures import download_fixtures_by_filters

# df_seasons = load_existing_seasons()

# # Descargar fixtures solo de Argentina
# stats = download_fixtures_by_filters(
#     df_seasons, 
#     pais='Argentina',
#     skip_existing=True  # No re-descargar archivos que ya existen
# )

###############################################################################

# # 2. Solo Sudamérica
# stats = download_fixtures_by_filters(
#     df_seasons, 
#     continente='South America',
#     skip_existing=True
# )

###############################################################################

# # 3. Una competición específica
# stats = download_fixtures_by_filters(
#     df_seasons, 
#     competicion='Liga Profesional Argentina',
#     skip_existing=True
# )

###############################################################################

# # 4. Control granular con la clase directamente
# from scraping_fixtures import FixtureScraper

# scraper = FixtureScraper()

# # Configurar delays más conservadores
# scraper.set_delay_range(2.0, 4.0)

# # Actualizar credenciales si cambian
# scraper.set_api_credentials('nueva_key', 'nuevo_callback')

# # Procesar con filtros múltiples
# filters = {
#     'continente': 'South America',
#     'pais': ['Argentina', 'Brasil', 'Chile']
# }

# stats = scraper.process_seasons(
#     df_seasons, 
#     filters=filters,
#     skip_existing=True,
#     start_index=10,  # Empezar desde la 10
#     limit=50         # Procesar solo 50
# )

###############################################################################

# # En lugar de todo ese código largo, solo esto:
# from scraping_seasons import load_existing_seasons
# from scraping_fixtures import download_fixtures_by_filters

# # Cargar temporadas
# df_seasons = load_existing_seasons()

# # Filtrar y descargar (reemplaza tu código actual)
# stats = download_fixtures_by_filters(df_seasons, pais='Argentina')

# print(f"✅ Descargadas {stats['success']} fixtures de Argentina")
# print(f"⏭️ Saltadas {stats['skipped']} (ya existían)")
# print(f"❌ Errores: {stats['errors']}")

###############################################################################

# # Esto ya no dará error
# from scraping_fixtures import download_fixtures_by_filters
# from scraping_seasons import load_existing_seasons

# df_seasons = load_existing_seasons()

# # Funciona perfectamente 
# stats = download_fixtures_by_filters(
#     df_seasons,
#     pais='Argentina',
#     limit=2,           # ✅ Ahora va al lugar correcto
#     skip_existing=True
# )

# # Si necesitas cambiar las credenciales de API
# stats = download_fixtures_by_filters(
#     df_seasons,
#     pais='Argentina',
#     limit=5,
#     sdapi_outlet_key='tu_nueva_key',    # Para el constructor
#     callback_id='tu_nuevo_callback'     # Para el constructor
# )

# stats = download_fixtures_by_filters(
#     df_seasons,
#     continente='South America',  # Filtra por continente
#     skip_existing=True
# )


###############################################################################

# # Cuando obtengas nuevas credenciales
# scraper = FixtureScraper()
# scraper.set_api_credentials('nueva_outlet_key', 'nuevo_callback_id')

# %%
# SI NO SE DESEA ACTUALIZAR LAS SESIONES DE TODO EL MUNDO EMPEZAR DESDE ACA
from scraping_seasons import load_existing_seasons

df_seasons = load_existing_seasons()
# Out:
# ✅ Temporadas cargadas desde: data/todas_las_temporadas.csv

# %%
df_seasons = df_seasons[df_seasons['continente'] == 'World']
df_seasons
# Out:
#       continente  pais            competicion             id_competicion  \
# 24270      World  FIFA         FIFA World Cup  70excpe1synn9kadnbppahdn7
# 24271      World  FIFA         FIFA World Cup  70excpe1synn9kadnbppahdn7
# 24272      World  FIFA         FIFA World Cup  70excpe1synn9kadnbppahdn7
# 24273      World  FIFA         FIFA World Cup  70excpe1synn9kadnbppahdn7
# 24274      World  FIFA         FIFA World Cup  70excpe1synn9kadnbppahdn7
# ...          ...   ...                    ...                        ...
# 48831      World  FIFA   Yongchuan Tournament  f1r379mu8rr23p1c1a7ay16qy
# 48832      World  FIFA   Yongchuan Tournament  f1r379mu8rr23p1c1a7ay16qy
# 48833      World  FIFA  Youth Club Friendlies  13g6xmizt8b2iq5zkdiiepu9m
# 48834      World  FIFA  Youth Club Friendlies  13g6xmizt8b2iq5zkdiiepu9m
# 48835      World  FIFA  Youth Club Friendlies  13g6xmizt8b2iq5zkdiiepu9m
#
#                                          url_competicion  \
# 24270  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24271  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24272  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24273  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24274  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# ...                                                  ...
# 48831  https://www.scoresway.com/en_GB/soccer/yongchu...
# 48832  https://www.scoresway.com/en_GB/soccer/yongchu...
# 48833  https://www.scoresway.com/en_GB/soccer/youth-c...
# 48834  https://www.scoresway.com/en_GB/soccer/youth-c...
# 48835  https://www.scoresway.com/en_GB/soccer/youth-c...
#
#                     temporada  \
# 24270  2026 Canada/Mexico/USA
# 24271              2022 Qatar
# 24272             2018 Russia
# 24273             2014 Brazil
# 24274       2010 South Africa
# ...                       ...
# 48831                    2018
# 48832                    2017
# 48833                    2016
# 48834                    2015
# 48835                    2014
#
#                                            url_temporada  \
# 24270  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24271  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24272  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24273  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24274  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# ...                                                  ...
# 48831  https://www.scoresway.com/en_GB/soccer/yongchu...
# 48832  https://www.scoresway.com/en_GB/soccer/yongchu...
# 48833  https://www.scoresway.com/en_GB/soccer/youth-c...
# 48834  https://www.scoresway.com/en_GB/soccer/youth-c...
# 48835  https://www.scoresway.com/en_GB/soccer/youth-c...
#
#                                           url_resultados
# 24270  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24271  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24272  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24273  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# 24274  https://www.scoresway.com/en_GB/soccer/fifa-wo...
# ...                                                  ...
# 48831  https://www.scoresway.com/en_GB/soccer/yongchu...
# 48832  https://www.scoresway.com/en_GB/soccer/yongchu...
# 48833  https://www.scoresway.com/en_GB/soccer/youth-c...
# 48834  https://www.scoresway.com/en_GB/soccer/youth-c...
# 48835  https://www.scoresway.com/en_GB/soccer/youth-c...
#
# [1923 rows x 8 columns]

# %%
df_seasons=df_seasons[df_seasons['competicion']=='FIFA U20 World Cup']
df_seasons=df_seasons[df_seasons['temporada']=='2025 Chile']
df_seasons
# Out:
#       continente  pais         competicion             id_competicion  \
# 24681      World  FIFA  FIFA U20 World Cup  6thk4rltubz0yjy35ru5dlo4x
# 48286      World  FIFA  FIFA U20 World Cup  6thk4rltubz0yjy35ru5dlo4x
#
#                                          url_competicion   temporada  \
# 24681  https://www.scoresway.com/en_GB/soccer/fifa-u2...  2025 Chile
# 48286  https://www.scoresway.com/en_GB/soccer/fifa-u2...  2025 Chile
#
#                                            url_temporada  \
# 24681  https://www.scoresway.com/en_GB/soccer/fifa-u2...
# 48286  https://www.scoresway.com/en_GB/soccer/fifa-u2...
#
#                                           url_resultados
# 24681  https://www.scoresway.com/en_GB/soccer/fifa-u2...
# 48286  https://www.scoresway.com/en_GB/soccer/fifa-u2...

# %%
from scraping_fixture import smart_download_fixtures

# # Continuar desde donde se quedó
stats = smart_download_fixtures(
    df_seasons,
    pais='FIFA',
    continente='World',
    restart_from_zero=True,  # No borrar existentes
    #     restart_from_zero=True,  # 🔥 Borra y empieza de cero
    batch_size=10000000000           # Procesar 150 más
)

# # O empezar de cero solo para Sudamérica
# stats = smart_download_fixtures(
#     df_seasons,
#     continente='South America',
#     restart_from_zero=True,
#     batch_size=200
# )
# Out:
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🎯 Filtros aplicados: {'continente': 'World', 'pais': 'FIFA'}
# 📋 Temporadas a procesar: 2
# 🔥 Modo reinicio: Borrando fixtures existentes...
# 🗑️  Eliminados 1 fixtures existentes
# 🚀 Empezando descarga desde temporada 1/2
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando descarga de fixtures...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
#    - Rango: 0 a 1
#
# 📋 Procesando 1/2: FIFA U20 World Cup - 2025 Chile
# 🌐 API URL: https://api.performfeeds.com/soccerdata/match/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&live=yes&_pgSz=400&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
# ✅ Fixture guardado: data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/fixture.json
#
# 📋 Procesando 2/2: FIFA U20 World Cup - 2025 Chile
# 🌐 API URL: https://api.performfeeds.com/soccerdata/match/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&live=yes&_pgSz=400&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
# ✅ Fixture guardado: data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/fixture.json
#
# ==================================================
# 📊 RESUMEN FINAL
# ==================================================
# ⏰ Tiempo total: 5.6 segundos
# 📋 Temporadas procesadas: 2/2
# ✅ Exitosas: 2
# ⏭️  Saltadas (ya existían): 0
# ❌ Con errores: 0
# ⚡ Velocidad promedio: 21.51 temporadas/minuto
#
# 📈 Progreso total: 2/2 (100.0%)

# %%
print(f"✅ Total de Temporadas {stats['total_seasons']}")
print(f"✅ Procesadas {stats['processed']}")
print(f"✅ Descargados {stats['success']} eventos")
print(f"⏭️ Saltados {stats['skipped']} (ya existían)")
print(f"❌ Errores: {stats['errors']}")
# Out:
# ✅ Total de Temporadas 2
# ✅ Procesadas 2
# ✅ Descargados 2 eventos
# ⏭️ Saltados 0 (ya existían)
# ❌ Errores: 0

# %%
# # Esto ya no dará error
# from scraping_fixtures import download_fixtures_by_filters
# from scraping_seasons import load_existing_seasons

# df_seasons = load_existing_seasons()

# # Funciona perfectamente 
# stats = download_fixtures_by_filters(
#     df_seasons,
#     pais='Argentina',
#     limit=2,           # ✅ Ahora va al lugar correcto
#     skip_existing=True
# )

# # Si necesitas cambiar las credenciales de API
# stats = download_fixtures_by_filters(
#     df_seasons,
#     pais='Argentina',
#     limit=5,
#     sdapi_outlet_key='tu_nueva_key',    # Para el constructor
#     callback_id='tu_nuevo_callback'     # Para el constructor
# )


# # Si se corta, usa esto para continuar:
# from scraping_fixtures import resume_fixtures_download

# stats = resume_fixtures_download(df_seasons, pais='Argentina', batch_size=100)

# %% [markdown]
# # PROCESAR FIXTURE

# %%
# # 1. Filtros inteligentes:

# # Solo Argentina
# df_arg = process_matches_by_filters(df_seasons, pais='Argentina')

# # Solo Brasil
# df_bra = process_matches_by_filters(df_seasons, pais='Brasil') 

# # Solo Liga Argentina
# df_liga = process_matches_by_filters(df_seasons, competicion='Liga Profesional Argentina')

# # Toda Sudamérica
# df_sa = process_matches_by_filters(df_seasons, continente='South America')

# #####################################################

# # 2. Control total con la clase:

# from processing_fixtures import FixtureProcessor

# processor = FixtureProcessor()

# # Procesar con configuración personalizada
# df_partidos = processor.crear_dataframe_partidos(
#     df_seasons,
#     filters={'continente': 'South America'},
#     save_results=True,
#     output_dir='data/custom_output'  # Directorio personalizado
# )

# #####################################################

# # 3. Información mucho más detallada:
# # El DataFrame ahora incluye:
# print(df_partidos.columns.tolist())
# # ['Fecha', 'Hora', 'Equipo_Local', 'Equipo_Visitante', 'Estadio', 
# #  'Partido_ID', 'Continente', 'Pais', 'Competicion', 'Temporada',
# #  'URL_Partido', 'Estado_Partido', 'Nivel_Cobertura', 'Asistencia',
# #  'Clima_Temperatura', 'Clima_Condiciones', etc.]

# #####################################################

# # 1. Solo archivos individuales (lo que quieres):
# df_partidos = process_matches_by_filters(
#     df_seasons,
#     pais='Argentina',
#     save_individual=True,     # ✅ Junto a cada fixture.json
#     save_consolidated=False   # ❌ Sin archivo consolidado
# )

# #2. Solo archivo consolidado (comportamiento anterior):
# df_partidos = process_matches_by_filters(
#     df_seasons,
#     pais='Argentina',
#     save_individual=False,    # ❌ Sin archivos individuales
#     save_consolidated=True    # ✅ Un archivo grande
# )

# #3. Ambos (lo mejor de ambos mundos):
# df_partidos = process_matches_by_filters(
#     df_seasons,
#     pais='Argentina',
#     save_individual=True,     # ✅ Junto a cada fixture.json
#     save_consolidated=True    # ✅ También archivo consolidado
# )

# %%
from scraping_seasons import load_existing_seasons
from processing_fixtures import process_matches_by_filters

# df_seasons = load_existing_seasons()

# ESTO ES LO QUE QUIERES - Guardar junto a cada fixture.json
df_partidos = process_matches_by_filters(
    df_seasons,
    pais='FIFA',
    continente='World',
    save_individual=True,    # ✅ Guarda junto a cada fixture.json
    save_consolidated=False  # ❌ No crear archivo consolidado
)

print(f"✅ Procesados {len(df_partidos)} partidos de Argentina")
# Out:
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando procesamiento de fixtures...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
# 📋 Procesando (24682/2): FIFA U20 World Cup - 2025 Chile
# ✅ Procesado data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/fixture.json: 52 partidos
# 💾 Guardado individual: 52 partidos en data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile
# 📋 Procesando (48287/2): FIFA U20 World Cup - 2025 Chile
# ✅ Procesado data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/fixture.json: 52 partidos
# 💾 Guardado individual: 52 partidos en data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile
#
# ============================================================
# 📊 RESUMEN FINAL DEL PROCESAMIENTO
# ============================================================
# 📁 Archivos procesados: 2
# ⚠️  Archivos omitidos: 0
# ❌ Archivos con error: 0
# ⚽ Total partidos extraídos: 104
#
# 📈 Estadísticas de partidos:
#    - Competiciones únicas: 1
#    - Países únicos: 1
#    - Equipos únicos: 24
#    - Rango de fechas: 2025-09-27 a 2025-10-19
#
# 🔍 Filtros aplicados: {'continente': 'World', 'pais': 'FIFA'}
# ✅ Procesados 104 partidos de Argentina

# %% [markdown]
# # EVENTOS DE PARTIDOS

# %%
# # 1. Función inteligente (auto-continúa):
# from scraping_match_events import smart_download_events

# # Si se corta, automáticamente detecta desde dónde continuar
# stats = smart_download_events(
#     df_partidos,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=200,           # Procesar 200 partidos
#     sleep_time=1.0
# )

######################################################################

# #2. Empezar de cero (borrar existentes):
# # Borrar eventos existentes y empezar limpio
# stats = smart_download_events(
#     df_partidos,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=100,
#     sleep_time=1.5
# )

######################################################################

# #3. Filtros inteligentes:
# # Solo Sudamérica
# stats = download_match_events(df_partidos, continente='South America')

# # Solo Liga Argentina
# stats = download_match_events(df_partidos, competicion='Liga Profesional Argentina')

# # Múltiples filtros
# stats = download_match_events(
#     df_partidos, 
#     continente='South America',
#     pais='Argentina'
# )

######################################################################

# #Opción más fácil (reemplaza directo):
# # En lugar de tu función descargar_match_events(), usa esto:
# from scraping_match_events import download_match_events

# # Cargar tus partidos
# df_partidos = pd.read_parquet('data/South America/todos_los_partidos.parquet')

# # Descargar eventos (reemplaza tu código actual)
# stats = download_match_events(
#     df_partidos,
#     # pais='Argentina',        # Opcional: filtrar por país
#     # continente='South America', # Opcional: filtrar por continente
#     sleep_time=1.0,            # Tu sleep_time actual
#     skip_existing=True         # No re-descargar existentes
# )

# print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")

######################################################################

# #Opción inteligente (si se puede cortar):
# # Usa esta si quieres que auto-detecte desde dónde continuar
# from scraping_match_events import smart_download_events

# stats = smart_download_events(
#     df_partidos,
#     pais='Argentina',          # Filtro opcional
#     restart_from_zero=False,   # False = continuar, True = empezar de cero
#     batch_size=200,            # Procesar 200 partidos
#     sleep_time=1.0
# )

######################################################################

# # Control granular con la clase:
# from scraping_match_events import MatchEventScraper

# scraper = MatchEventScraper()

# # Configurar credenciales si cambian
# scraper.set_api_credentials('nueva_outlet_key', 'nuevo_callback')

# # Configurar delay más conservador
# scraper.set_delay(2.0)

# # Procesar con control total
# stats = scraper.descargar_eventos_masivo(
#     df_partidos,
#     filters={'pais': 'Argentina'},
#     start_index=100,  # Continuar desde el partido 100
#     limit=50          # Solo procesar 50 más
# )

# %%
len(df_partidos)
# Out:
# 104

# %%
# Opción 1: Súper simple
from scraping_match_events import smart_download_events

# stats = download_match_events(
#     df_partidos,
#     pais='Chile',  # Filtro automático
#     sleep_time=1.0
# )

stats = smart_download_events(
    df_partidos,
    # pais='Brazil',
    # continente='Asia',
    restart_from_zero=False,  # Continuar desde donde se quedó
    batch_size=2000000000,           # Procesar 200 partidos
    sleep_time=1.0
)

print(f"✅ Descargados {stats['exitosos']} eventos")
print(f"⏭️ Saltados {stats['saltados']} (ya existían)")
print(f"❌ Errores: {stats['fallos']}")
# Out:
53] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 1sa6upfr2zolz0avgp2de36l0_2025-10-18_None_None.json
#
# 📋 [52/53] Procesando: N/A vs N/A
# 🌐 Descargando eventos: None vs None
# ✅ Guardado: asnvca23qvkl9q8ys3h038j6c_2025-10-19_None_None.json
#
# 📋 [53/53] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): asnvca23qvkl9q8ys3h038j6c_2025-10-19_None_None.json
#
# ============================================================
# 📊 RESUMEN FINAL - DESCARGA DE EVENTOS
# ============================================================
# ⏰ Tiempo total: 55.2 segundos (0.9 minutos)
# 📋 Partidos procesados: 53/53
# ✅ Descargas exitosas: 28
# ⏭️  Archivos saltados (ya existían): 25
# ❌ Fallos: 0
# ⚡ Velocidad promedio: 57.66 partidos/minuto
# 📈 Tasa de éxito: 52.8%
# ✅ Descargados 28 eventos
# ⏭️ Saltados 25 (ya existían)
# ❌ Errores: 0

# %%
print(f"✅ Descargados {stats['success']} eventos")
print(f"⏭️ Saltados {stats['skipped']} (ya existían)")
print(f"❌ Errores: {stats['errors']}")
# Out:
# ✅ Descargados 2 eventos
# ⏭️ Saltados 0 (ya existían)
# ❌ Errores: 0

# %% [markdown]
# # MATCH STATS

# %%
# # 1. Función inteligente (auto-continúa):
# from scraping_match_stats import smart_download_stats

# # Si se corta, automáticamente detecta desde dónde continuar
# stats = smart_download_stats(
#     df_partidos,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=200,           # Procesar 200 partidos
#     sleep_time=1.0
# )

################################################################################

# # 2. Empezar de cero (borrar existentes):
# # Borrar estadísticas existentes y empezar limpio
# stats = smart_download_stats(
#     df_partidos,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=100,
#     sleep_time=1.5
# )

################################################################################

# # 3. Filtros flexibles:
# # Solo Sudamérica
# stats = download_match_stats(df_partidos, continente='South America')

# # Solo Liga Argentina  
# stats = download_match_stats(df_partidos, competicion='Liga Profesional Argentina')

# # Combinaciones
# stats = download_match_stats(
#     df_partidos,
#     continente='South America',
#     pais='Argentina',
#     sleep_time=2.0
# )

################################################################################


# # Opción directa (reemplaza tu función):
# # En lugar de tu función descargar_match_stats(), usa esto:
# from scraping_match_stats import download_match_stats

# # Cargar tus partidos
# df_partidos = pd.read_parquet('data/South America/todos_los_partidos.parquet')

# # Descargar estadísticas (reemplaza tu código actual)
# stats = download_match_stats(
#     df_partidos,
#     pais='Argentina',         # Opcional: filtrar por país
#     sleep_time=1.0,          # Tu sleep_time actual
#     skip_existing=True       # No re-descargar existentes
# )

# print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")

################################################################################

# # Opción inteligente (reanudable):
# # Usa esta si quieres que auto-detecte desde dónde continuar
# from scraping_match_stats import smart_download_stats

# stats = smart_download_stats(
#     df_partidos,
#     pais='Argentina',          # Filtro opcional
#     restart_from_zero=False,   # False = continuar, True = empezar de cero
#     batch_size=200,            # Procesar 200 partidos
#     sleep_time=1.0
# )

# print(f"📈 Progreso: {stats['procesados']}/{stats['total_partidos']}")

# %%
# Opción 1: Súper simple
from scraping_match_stats import download_match_stats

stats = download_match_stats(
    df_partidos,
    # pais='Brazil',
    # continente='Asia',
    sleep_time=1.0
)

print(f"✅ Descargadas {stats['exitosos']} estadísticas")
print(f"⏭️ Saltadas {stats['saltados']} (ya existían)")
print(f"❌ Errores: {stats['fallos']}")
# Out:
104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): dz5upuaxufrnhtc3qaw1d4utw_2025-10-09_None_None.json
#
# 📋 [89/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: 56snup64l70bjl3sysf3vsoic_2025-10-11_None_None.json
#
# 📋 [90/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: 57m1kmbpkgsymubonfv6n6plg_2025-10-11_None_None.json
#
# 📋 [91/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 56snup64l70bjl3sysf3vsoic_2025-10-11_None_None.json
#
# 📋 [92/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 57m1kmbpkgsymubonfv6n6plg_2025-10-11_None_None.json
#
# 📋 [93/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: 58evb084np1ksqtysakewcjkk_2025-10-12_None_None.json
#
# 📋 [94/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: 597qc9g8w1zihzmipfizt0c2c_2025-10-12_None_None.json
#
# 📋 [95/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 58evb084np1ksqtysakewcjkk_2025-10-12_None_None.json
#
# 📋 [96/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 597qc9g8w1zihzmipfizt0c2c_2025-10-12_None_None.json
#
# 📋 [97/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: 5p1vqaeh3lbwxw9sp4wos13x0_2025-10-15_None_None.json
#
# 📋 [98/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: 5o8eu9171gxpzd3w6pd8i1s0k_2025-10-15_None_None.json
#
# 📋 [99/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 5o8eu9171gxpzd3w6pd8i1s0k_2025-10-15_None_None.json
#
# 📋 [100/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 5p1vqaeh3lbwxw9sp4wos13x0_2025-10-15_None_None.json
#
# 📊 Progreso: 100/104 (96.2%)
#    ⚡ Velocidad: 66.10 partidos/minuto
#    ✅ Exitosos: 50
#    ⏭️  Saltados: 50
#    ❌ Fallos: 0
#    ⏰ Tiempo estimado restante: 0.1 minutos
#
# 📋 [101/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: 1sa6upfr2zolz0avgp2de36l0_2025-10-18_None_None.json
#
# 📋 [102/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): 1sa6upfr2zolz0avgp2de36l0_2025-10-18_None_None.json
#
# 📋 [103/104] Procesando: N/A vs N/A
# 📊 Descargando stats: None vs None
# ✅ Guardado: asnvca23qvkl9q8ys3h038j6c_2025-10-19_None_None.json
#
# 📋 [104/104] Procesando: N/A vs N/A
# ⏭️  Archivo ya existe (saltando): asnvca23qvkl9q8ys3h038j6c_2025-10-19_None_None.json
#
# ============================================================
# 📊 RESUMEN FINAL - DESCARGA DE ESTADÍSTICAS
# ============================================================
# ⏰ Tiempo total: 94.6 segundos (1.6 minutos)
# 📋 Partidos procesados: 104/104
# ✅ Descargas exitosas: 52
# ⏭️  Archivos saltados (ya existían): 52
# ❌ Fallos: 0
# ⚡ Velocidad promedio: 65.97 partidos/minuto
# 📈 Tasa de éxito: 50.0%
# ✅ Descargadas 52 estadísticas
# ⏭️ Saltadas 52 (ya existían)
# ❌ Errores: 0

# %%
print(f"✅ Descargadas {stats['exitosos']} estadísticas")
print(f"⏭️ Saltadas {stats['saltados']} (ya existían)")
print(f"❌ Errores: {stats['fallos']}")

# %% [markdown]
# # STANDINGS

# %%
# # Opción 1: Súper simple
# from scraping_seasons import load_existing_seasons
# from scraping_standings import download_standings_by_filters

# df_seasons = load_existing_seasons()

# stats = download_standings_by_filters(
#     df_seasons,
#     pais='Argentina'  # Filtro automático
# )

# print(f"✅ Descargadas {stats['exitosos']} tablas de posiciones")
# print(f"⏭️ Saltadas {stats['saltados']} (ya existían)")
# print(f"❌ Errores: {stats['fallos']}")

# #####################################################################

# # 1. Función inteligente (auto-continúa):
# from scraping_standings import smart_download_standings

# # Si se corta, automáticamente detecta desde dónde continuar
# stats = smart_download_standings(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=50             # Procesar 50 temporadas
# )

# #####################################################################

# # 2. Empezar de cero (borrar existentes):
# # Borrar standings existentes y empezar limpio
# stats = smart_download_standings(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=100
# )

# #####################################################################

# # 3. Filtros flexibles:
# # Solo Sudamérica
# stats = download_standings_by_filters(df_seasons, continente='South America')

# # Solo Liga Argentina
# stats = download_standings_by_filters(df_seasons, competicion='Liga Profesional Argentina')

# # Combinaciones
# stats = download_standings_by_filters(
#     df_seasons,
#     continente='South America',
#     pais='Argentina'
# )

#####################################################################

# Opción inteligente (reanudable):
# Usa esta si quieres que auto-detecte desde dónde continuar
# from scraping_standings import smart_download_standings

# stats = smart_download_standings(
#     df_seasons,
#     pais='Argentina',         # Filtro opcional
#     restart_from_zero=False,  # False = continuar, True = empezar de cero
#     batch_size=100            # Procesar 100 temporadas
# )

# %%
# En lugar de tu loop, usa esto:
from scraping_seasons import load_existing_seasons
from scraping_standings import download_standings_by_filters

# Cargar temporadas (no partidos)
# df_seasons = load_existing_seasons()

# Descargar standings (reemplaza tu código actual)
stats = download_standings_by_filters(
    df_seasons,
    pais='FIFA',
    continente='World',
    skip_existing=True      # No re-descargar existentes
)

print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")
# Out:
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando descarga de standings...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
#    - Rango: 0 a 1
#    - Delay: 1.0-2.0 segundos
#
# 📋 Procesando 1/2: FIFA U20 World Cup - 2025 Chile
# 🏆 API URL: https://api.performfeeds.com/soccerdata/standings/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&live=yes&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
# ✅ Standings guardado: data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/standings.json
#
# 📋 Procesando 2/2: FIFA U20 World Cup - 2025 Chile
# ⏭️  Archivo ya existe (saltando): data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/standings.json
#
# ============================================================
# 🏆 RESUMEN FINAL - DESCARGA DE STANDINGS
# ============================================================
# ⏰ Tiempo total: 3.0 segundos (0.0 minutos)
# 📋 Temporadas procesadas: 2/2
# ✅ Descargas exitosas: 1
# ⏭️  Archivos saltados (ya existían): 1
# ❌ Fallos: 0
# ⚡ Velocidad promedio: 40.03 temporadas/minuto
# 📈 Tasa de éxito: 50.0%
# Exitosos: 1, Fallos: 0

# %%
print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")
# Out:
# Exitosos: 1, Fallos: 0

# %% [markdown]
# # MATCH

# %%
# # Opción 1: Súper simple
# from scraping_seasons import load_existing_seasons
# from scraping_match_data import download_match_data_by_filters

# df_seasons = load_existing_seasons()

# stats = download_match_data_by_filters(
#     df_seasons,
#     pais='Argentina'  # Filtro automático
# )

# print(f"✅ Descargados {stats['exitosos']} archivos de match data")
# print(f"⏭️ Saltados {stats['saltados']} (ya existían)")
# print(f"❌ Errores: {stats['fallos']}")

# #######################################################################

# # 1. Función inteligente (auto-continúa):

# from scraping_match_data import smart_download_match_data

# # Si se corta, automáticamente detecta desde dónde continuar
# stats = smart_download_match_data(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=50             # Procesar 50 temporadas
# )

# #######################################################################

# # 2. Empezar de cero (borrar existentes):

# # Borrar match data existentes y empezar limpio
# stats = smart_download_match_data(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=100
# )

# #######################################################################

# # 3. Filtros flexibles:
# # Solo Sudamérica
# stats = download_match_data_by_filters(df_seasons, continente='South America')

# # Solo Liga Argentina
# stats = download_match_data_by_filters(df_seasons, competicion='Liga Profesional Argentina')

# # Combinaciones
# stats = download_match_data_by_filters(
#     df_seasons,
#     continente='South America',
#     pais='Argentina'
# )

# #######################################################################

# # Opción directa (reemplaza tu loop):
# # En lugar de tu loop, usa esto:
# from scraping_seasons import load_existing_seasons
# from scraping_match_data import download_match_data_by_filters

# # Cargar temporadas
# df_seasons = load_existing_seasons()

# # Descargar match data (reemplaza tu código actual)
# stats = download_match_data_by_filters(
#     df_seasons,
#     # pais='Argentina',     # Opcional: filtrar por país
#     skip_existing=True      # No re-descargar existentes
# )

# print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")

#######################################################################

# Opción inteligente (reanudable):
# # Usa esta si quieres que auto-detecte desde dónde continuar
# from scraping_match_data import smart_download_match_data

# stats = smart_download_match_data(
#     df_seasons,
#     pais='Argentina',         # Filtro opcional
#     restart_from_zero=False,  # False = continuar, True = empezar de cero
#     batch_size=100            # Procesar 100 temporadas
# )

# %%
# En lugar de tu loop, usa esto:
from scraping_seasons import load_existing_seasons
from scraping_match_data import download_match_data_by_filters

# Cargar temporadas
# df_seasons = load_existing_seasons()

# Descargar match data (reemplaza tu código actual)
stats = download_match_data_by_filters(
    df_seasons,
    # pais='Brazil',     # Opcional: filtrar por país
    pais='FIFA',
    continente='World',
    skip_existing=True      # No re-descargar existentes
)

print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")
# Out:
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando descarga de datos de partidos...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
#    - Rango: 0 a 1
#    - Delay: 1.0-2.0 segundos
#
# 📋 Procesando 1/2: FIFA U20 World Cup - 2025 Chile
# ⚽ API URL: https://api.performfeeds.com/soccerdata/match/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&live=yes&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
# ✅ Match guardado: data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/match.json
#
# 📋 Procesando 2/2: FIFA U20 World Cup - 2025 Chile
# ⏭️  Archivo ya existe (saltando): data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/match.json
#
# ============================================================
# ⚽ RESUMEN FINAL - DESCARGA DE DATOS DE PARTIDOS
# ============================================================
# ⏰ Tiempo total: 2.6 segundos (0.0 minutos)
# 📋 Temporadas procesadas: 2/2
# ✅ Descargas exitosas: 1
# ⏭️  Archivos saltados (ya existían): 1
# ❌ Fallos: 0
# ⚡ Velocidad promedio: 45.81 temporadas/minuto
# 📈 Tasa de éxito: 50.0%
# Exitosos: 1, Fallos: 0

# %%
print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")
# Out:
# Exitosos: 3743, Fallos: 0

# %% [markdown]
# # SQUADS

# %%
# # Opción 1: Súper simple
# from scraping_seasons import load_existing_seasons
# from scraping_squads import download_squads_by_filters

# df_seasons = load_existing_seasons()

# stats = download_squads_by_filters(
#     df_seasons,
#     pais='Argentina',  # Filtro automático
#     detailed=True      # Información detallada de jugadores
# )

# print(f"✅ Descargados {stats['exitosos']} planteles")
# print(f"⏭️ Saltados {stats['saltados']} (ya existían)")
# print(f"❌ Errores: {stats['fallos']}")

# #####################################################################

# # 1. Configuración de paginación:

# from scraping_squads import download_squads_by_filters

# stats = download_squads_by_filters(
#     df_seasons,
#     pais='Argentina',
#     page_size=100,      # Más jugadores por página
#     detailed=True       # Información completa de jugadores
# )

# #####################################################################

# # 2. Función inteligente (auto-continúa):
# from scraping_squads import smart_download_squads

# # Si se corta, automáticamente detecta desde dónde continuar
# stats = smart_download_squads(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=50,            # Procesar 50 temporadas
#     detailed=True             # Información detallada
# )

# #####################################################################

# # 3. Empezar de cero (borrar existentes):
# # Borrar squads existentes y empezar limpio
# stats = smart_download_squads(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=100,
#     page_size=75,             # Más elementos por página
#     detailed=True
# )

# #####################################################################

# # 4. Control avanzado con la clase:
# from scraping_squads import SquadsScraper

# scraper = SquadsScraper()

# # Configurar paginación personalizada
# scraper.set_pagination_config(
#     page_size=100,      # 100 jugadores por página
#     page_number=1,      # Primera página
#     detailed=True       # Información completa
# )

# # Configurar delays más conservadores para planteles
# scraper.set_delay_range(2.0, 4.0)

# # Procesar
# stats = scraper.process_seasons(
#     df_seasons,
#     filters={'pais': 'Argentina'},
#     start_index=50,
#     limit=25
# )

# #####################################################################

# # Opción directa (reemplaza tu loop):
# # En lugar de tu loop, usa esto:
# from scraping_seasons import load_existing_seasons
# from scraping_squads import download_squads_by_filters

# # Cargar temporadas
# df_seasons = load_existing_seasons()

# # Descargar planteles (reemplaza tu código actual)
# stats = download_squads_by_filters(
#     df_seasons,
#     # pais='Argentina',     # Opcional: filtrar por país
#     detailed=True,          # Información completa de jugadores
#     page_size=50,          # Jugadores por página
#     skip_existing=True     # No re-descargar existentes
# )

# print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")

# #####################################################################

# # Opción inteligente (reanudable):
# # Usa esta si quieres que auto-detecte desde dónde continuar
# from scraping_squads import smart_download_squads

# stats = smart_download_squads(
#     df_seasons,
#     pais='Argentina',         # Filtro opcional
#     restart_from_zero=False,  # False = continuar, True = empezar de cero
#     batch_size=100,           # Procesar 100 temporadas
#     detailed=True             # Información detallada de jugadores
# )

# %%
# Opción 1: Súper simple
from scraping_seasons import load_existing_seasons
from scraping_squads import download_squads_by_filters

# df_seasons = load_existing_seasons()

stats = download_squads_by_filters(
    df_seasons,
    # pais='Argentina',  # Filtro automático
    pais='FIFA',
    continente='World',
    detailed=True      # Información detallada de jugadores
)

print(f"✅ Descargados {stats['exitosos']} planteles")
print(f"⏭️ Saltados {stats['saltados']} (ya existían)")
print(f"❌ Errores: {stats['fallos']}")
# Out:
# 📄 Paginación configurada: 50 elementos/página, página 1, detallado: True
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando descarga de planteles...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
#    - Rango: 0 a 1
#    - Delay: 1.0-2.0 segundos
#    - Configuración: 50 elementos/página, detallado: True
#
# 📋 Procesando 1/2: FIFA U20 World Cup - 2025 Chile
# 👥 API URL: https://api.performfeeds.com/soccerdata/squads/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&_pgSz=50&_pgNm=1&detailed=yes&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
# ✅ Squads guardado: data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/squads.json
#
# 📋 Procesando 2/2: FIFA U20 World Cup - 2025 Chile
# ⏭️  Archivo ya existe (saltando): data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/squads.json
#
# ============================================================
# 👥 RESUMEN FINAL - DESCARGA DE PLANTELES
# ============================================================
# ⏰ Tiempo total: 3.3 segundos (0.1 minutos)
# 📋 Temporadas procesadas: 2/2
# ✅ Descargas exitosas: 1
# ⏭️  Archivos saltados (ya existían): 1
# ❌ Fallos: 0
# ⚡ Velocidad promedio: 35.98 temporadas/minuto
# 📈 Tasa de éxito: 50.0%
# ✅ Descargados 1 planteles
# ⏭️ Saltados 1 (ya existían)
# ❌ Errores: 0

# %%
print(f"✅ Descargados {stats['exitosos']} planteles")
print(f"⏭️ Saltados {stats['saltados']} (ya existían)")
print(f"❌ Errores: {stats['fallos']}")

# %% [markdown]
# # SEASON STATS

# %%
# #1. Función inteligente (auto-continúa):
# from scraping_season_stats import smart_download_season_stats

# # Si se corta, automáticamente detecta desde dónde continuar
# stats = smart_download_season_stats(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=25             # Menos temporadas porque cada una tiene muchos equipos
# )

# ##################################################################################

# # 2. Empezar de cero (borrar existentes):
# # Borrar seasonstats existentes y empezar limpio
# stats = smart_download_season_stats(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=50
# )

# ##################################################################################

# # 3. Control granular con la clase:
# from scraping_season_stats import SeasonStatsScraper

# scraper = SeasonStatsScraper()

# # Configurar delays más conservadores (muchas peticiones por temporada)
# scraper.set_delay_range(1.5, 3.0)

# # Procesar con control detallado
# stats = scraper.process_seasons(
#     df_seasons,
#     filters={'pais': 'Argentina'},
#     start_index=10,
#     limit=5  # Solo 5 temporadas porque cada una procesa muchos equipos
# )

# ##################################################################################

# # Opción directa (reemplaza tu loop):
# # ⚠️ IMPORTANTE: Primero asegúrate de tener squads.json descargados
# from scraping_squads import smart_download_squads
# stats = smart_download_squads(df_seasons, pais='Argentina')

# # Luego descargar estadísticas de temporada
# from scraping_season_stats import download_season_stats_by_filters

# # En lugar de tu loop, usa esto:
# stats = download_season_stats_by_filters(
#     df_seasons,
#     pais='Argentina',        # Opcional: filtrar por país
#     skip_existing=True       # No re-descargar existentes
# )

# print(f"Temporadas: {stats['exitosos']}, Equipos: {stats['equipos_exitosos']}")

# ##################################################################################

# # Opción inteligente (reanudable):
# # Usa esta si quieres que auto-detecte desde dónde continuar
# from scraping_season_stats import smart_download_season_stats

# stats = smart_download_season_stats(
#     df_seasons,
#     pais='Argentina',         # Filtro opcional
#     restart_from_zero=False,  # False = continuar, True = empezar de cero
#     batch_size=25             # Menos por temporada (cada una procesa muchos equipos)
# )

# %%
# Opción 1: Súper simple
from scraping_seasons import load_existing_seasons
from scraping_season_stats import download_season_stats_by_filters

# df_seasons = load_existing_seasons()

stats = download_season_stats_by_filters(
    df_seasons,
    # pais='Brazil'  # Filtro automático
    pais='FIFA',
    continente='World'
)

print(f"✅ Procesadas {stats['exitosos']} temporadas")
print(f"👥 Descargadas estadísticas de {stats['equipos_exitosos']} equipos")
print(f"❌ Errores: {stats['fallos']}")
# Out:
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando descarga de estadísticas de temporada...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
#    - Rango: 0 a 1
#    - Delay entre equipos: 1.0-2.0 segundos
#    ⚠️  Requiere archivos squads.json previos
#
# 📋 Procesando 1/2: FIFA U20 World Cup - 2025 Chile
# ✅ Extraídos 24 equipos del archivo squads.json
# 📊 Procesando estadísticas para 24 equipos...
#   📈 Descargando stats: Argentina U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=d6u776z1u68vhap9hp9zjuydw&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Argentina U20_d6u776z1u68vhap9hp9zjuydw.json
#   📈 Descargando stats: Australia U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=9892ealk5ilwe6p6esyxn383z&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Australia U20_9892ealk5ilwe6p6esyxn383z.json
#   📈 Descargando stats: Brazil U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=8j5t166ehedg5j7cule0gvctw&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Brazil U20_8j5t166ehedg5j7cule0gvctw.json
#   📈 Descargando stats: Chile U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=dji38hagdsdbvpicyptk3ya1h&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Chile U20_dji38hagdsdbvpicyptk3ya1h.json
#   📈 Descargando stats: Colombia U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=ezmda6w1an0hf804htq6dbdw0&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Colombia U20_ezmda6w1an0hf804htq6dbdw0.json
#   📈 Descargando stats: Cuba U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=6w3o62j2vskty0o5hhfmtg2yl&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Cuba U20_6w3o62j2vskty0o5hhfmtg2yl.json
#   📈 Descargando stats: Egypt U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=c5su71rfho2qdek52ie3w92wp&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Egypt U20_c5su71rfho2qdek52ie3w92wp.json
#   📈 Descargando stats: France U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=5hpwmngudtgits98k5ce2ckjh&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: France U20_5hpwmngudtgits98k5ce2ckjh.json
#   📈 Descargando stats: Italy U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=6x786yaxantdgjq0l4a1gc1v&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Italy U20_6x786yaxantdgjq0l4a1gc1v.json
#   📈 Descargando stats: Japan U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=dcwbos9a4ewky1texbtz9sb5d&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Japan U20_dcwbos9a4ewky1texbtz9sb5d.json
#   📈 Descargando stats: Korea Republic U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=2csfzqowk5wdjyufr7jam8txd&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Korea Republic U20_2csfzqowk5wdjyufr7jam8txd.json
#   📈 Descargando stats: Mexico U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=9x2gxl6xovekn482lxe6f8tap&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Mexico U20_9x2gxl6xovekn482lxe6f8tap.json
#   📈 Descargando stats: Morocco U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=a8lztquljwnour4ls6nniii0u&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Morocco U20_a8lztquljwnour4ls6nniii0u.json
#   📈 Descargando stats: New Caledonia U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=as4klflzok9qem1wc0bpxa6yp&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: New Caledonia U20_as4klflzok9qem1wc0bpxa6yp.json
#   📈 Descargando stats: New Zealand U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=tg1nnszuv0zr99ttlya5fy0m&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: New Zealand U20_tg1nnszuv0zr99ttlya5fy0m.json
#   📈 Descargando stats: Nigeria U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=24xy1ap3wamomfyyn00rzs79r&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Nigeria U20_24xy1ap3wamomfyyn00rzs79r.json
#   📈 Descargando stats: Norway U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=aaq4dfzfmafbop5976if2z88a&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Norway U20_aaq4dfzfmafbop5976if2z88a.json
#   📈 Descargando stats: Panama U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=90wmwkbdrgoi8zg5fx3dc6tet&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Panama U20_90wmwkbdrgoi8zg5fx3dc6tet.json
#   📈 Descargando stats: Paraguay U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=4regxj1097bvl2ktj8nmnb32i&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Paraguay U20_4regxj1097bvl2ktj8nmnb32i.json
#   📈 Descargando stats: Saudi Arabia U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=aierrdwlhgygpb74jqlk3mgv&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Saudi Arabia U20_aierrdwlhgygpb74jqlk3mgv.json
#   📈 Descargando stats: South Africa U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=feancmz08pxur7cxp179ylw0&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: South Africa U20_feancmz08pxur7cxp179ylw0.json
#   📈 Descargando stats: Spain U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=239ue2dajds38167m1q320iyi&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Spain U20_239ue2dajds38167m1q320iyi.json
#   📈 Descargando stats: Ukraine U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=dm4g3bexmcs96csbeb47l3o5j&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Ukraine U20_dm4g3bexmcs96csbeb47l3o5j.json
#   📈 Descargando stats: United States U20
# 📊 API URL: https://api.performfeeds.com/soccerdata/seasonstats/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&ctst=bo858sll0r8nayyt5smdu3pxs&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: United States U20_bo858sll0r8nayyt5smdu3pxs.json
# 📊 Temporada completada: 24 exitosos, 0 saltados, 0 fallidos
#
# 📋 Procesando 2/2: FIFA U20 World Cup - 2025 Chile
# ✅ Extraídos 24 equipos del archivo squads.json
# 📊 Procesando estadísticas para 24 equipos...
#   ⏭️  Equipo ya existe (saltando): Argentina U20
#   ⏭️  Equipo ya existe (saltando): Australia U20
#   ⏭️  Equipo ya existe (saltando): Brazil U20
#   ⏭️  Equipo ya existe (saltando): Chile U20
#   ⏭️  Equipo ya existe (saltando): Colombia U20
#   ⏭️  Equipo ya existe (saltando): Cuba U20
#   ⏭️  Equipo ya existe (saltando): Egypt U20
#   ⏭️  Equipo ya existe (saltando): France U20
#   ⏭️  Equipo ya existe (saltando): Italy U20
#   ⏭️  Equipo ya existe (saltando): Japan U20
#   ⏭️  Equipo ya existe (saltando): Korea Republic U20
#   ⏭️  Equipo ya existe (saltando): Mexico U20
#   ⏭️  Equipo ya existe (saltando): Morocco U20
#   ⏭️  Equipo ya existe (saltando): New Caledonia U20
#   ⏭️  Equipo ya existe (saltando): New Zealand U20
#   ⏭️  Equipo ya existe (saltando): Nigeria U20
#   ⏭️  Equipo ya existe (saltando): Norway U20
#   ⏭️  Equipo ya existe (saltando): Panama U20
#   ⏭️  Equipo ya existe (saltando): Paraguay U20
#   ⏭️  Equipo ya existe (saltando): Saudi Arabia U20
#   ⏭️  Equipo ya existe (saltando): South Africa U20
#   ⏭️  Equipo ya existe (saltando): Spain U20
#   ⏭️  Equipo ya existe (saltando): Ukraine U20
#   ⏭️  Equipo ya existe (saltando): United States U20
# 📊 Temporada completada: 0 exitosos, 24 saltados, 0 fallidos
#
# ======================================================================
# 📊 RESUMEN FINAL - DESCARGA DE ESTADÍSTICAS DE TEMPORADA
# ======================================================================
# ⏰ Tiempo total: 56.7 segundos (0.9 minutos)
# 📋 Temporadas procesadas: 2/2
# ✅ Temporadas exitosas: 1
# ❌ Temporadas fallidas: 1
# 👥 Total equipos procesados: 24
# 📈 Equipos exitosos: 24
# ⚡ Velocidad temporadas: 2.11/minuto
# ⚡ Velocidad equipos: 25.38/minuto
# 📈 Tasa de éxito equipos: 100.0%
# 📈 Tasa de éxito temporadas: 50.0%
# ✅ Procesadas 1 temporadas
# 👥 Descargadas estadísticas de 24 equipos
# ❌ Errores: 1

# %%
print(f"✅ Procesadas {stats['exitosos']} temporadas")
print(f"👥 Descargadas estadísticas de {stats['equipos_exitosos']} equipos")
print(f"❌ Errores: {stats['fallos']}")
# Out:
# ✅ Procesadas 0 temporadas
# 👥 Descargadas estadísticas de 0 equipos
# ❌ Errores: 8720

# %% [markdown]
# # RANKINGS

# %%
# #1. Función inteligente (auto-continúa):
# from scraping_rankings import smart_download_rankings

# # Si se corta, automáticamente detecta desde dónde continuar
# stats = smart_download_rankings(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=100             # Procesar 100 temporadas
# )

# ########################################################################

# # 2. Empezar de cero (borrar existentes):
# # Borrar rankings existentes y empezar limpio
# stats = smart_download_rankings(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=100
# )

# ########################################################################

# # 3. Filtros flexibles:
# # Solo Sudamérica
# stats = download_rankings_by_filters(df_seasons, continente='South America')

# # Solo Liga Argentina
# stats = download_rankings_by_filters(df_seasons, competicion='Liga Profesional Argentina')

# # Combinaciones múltiples
# stats = download_rankings_by_filters(
#     df_seasons,
#     continente='South America',
#     pais=['Argentina', 'Brasil', 'Chile']
# )

# ########################################################################

# # Opción directa (reemplaza tu loop):
# # En lugar de tu loop, usa esto:
# from scraping_seasons import load_existing_seasons
# from scraping_rankings import download_rankings_by_filters

# # Cargar temporadas
# df_seasons = load_existing_seasons()

# # Descargar rankings (reemplaza tu código actual)
# stats = download_rankings_by_filters(
#     df_seasons,
#     # pais='Argentina',     # Opcional: filtrar por país
#     skip_existing=True      # No re-descargar existentes
# )

# print(f"Exitosos: {stats['exitosos']}, Fallos: {stats['fallos']}")

# ########################################################################

# # Opción inteligente (reanudable):
# # Usa esta si quieres que auto-detecte desde dónde continuar
# from scraping_rankings import smart_download_rankings

# stats = smart_download_rankings(
#     df_seasons,
#     pais='Argentina',         # Filtro opcional
#     restart_from_zero=False,  # False = continuar, True = empezar de cero
#     batch_size=100            # Procesar 100 temporadas
# )

# %%
# Opción 1: Súper simple
from scraping_seasons import load_existing_seasons
from scraping_rankings import download_rankings_by_filters

# df_seasons = load_existing_seasons()

stats = download_rankings_by_filters(
    df_seasons,
    # pais='Brazil'  # Filtro automático
    # continente='Asia',
    pais='FIFA',
    continente='World',
)

print(f"✅ Descargados {stats['exitosos']} rankings")
print(f"⏭️ Saltados {stats['saltados']} (ya existían)")
print(f"❌ Errores: {stats['fallos']}")
# Out:
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando descarga de rankings...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
#    - Rango: 0 a 1
#    - Delay: 1.0-2.0 segundos
#
# 📋 Procesando 1/2: FIFA U20 World Cup - 2025 Chile
# 🏅 API URL: https://api.performfeeds.com/soccerdata/rankings/ft1tiv1inq7v1sk3y9tv12yh5/?_rt=c&tmcl=b4hz7xmd2qqeyz9ep9ultuuc4&_lcl=en&_fmt=jsonp&sps=widgets&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
# ✅ Rankings guardado: data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/rankings.json
#
# 📋 Procesando 2/2: FIFA U20 World Cup - 2025 Chile
# ⏭️  Archivo ya existe (saltando): data/World/FIFA/FIFA U20 World Cup_6thk4rltubz0yjy35ru5dlo4x/fifa-u20-world-cup-2025-chile/rankings.json
#
# ============================================================
# 🏅 RESUMEN FINAL - DESCARGA DE RANKINGS
# ============================================================
# ⏰ Tiempo total: 3.4 segundos (0.1 minutos)
# 📋 Temporadas procesadas: 2/2
# ✅ Descargas exitosas: 1
# ⏭️  Archivos saltados (ya existían): 1
# ❌ Fallos: 0
# ⚡ Velocidad promedio: 35.55 temporadas/minuto
# 📈 Tasa de éxito: 50.0%
# ✅ Descargados 1 rankings
# ⏭️ Saltados 1 (ya existían)
# ❌ Errores: 0

# %% [markdown]
# print(f"✅ Descargados {stats['exitosos']} rankings")
# print(f"⏭️ Saltados {stats['saltados']} (ya existían)")
# print(f"❌ Errores: {stats['fallos']}")

# %% [markdown]
# # PLAYER BIO

# %%
# #1. Opción simple (reemplaza tu código actual):
# # En lugar de tu loop actual, usa esto:
# from scraping_seasons import load_existing_seasons
# from scraping_player_bio import download_player_bio_by_filters

# # Cargar temporadas
# df_seasons = load_existing_seasons()

# # Descargar biografías de jugadores (requiere squads.json)
# stats = download_player_bio_by_filters(
#     df_seasons,
#     pais='Argentina',        # Filtro por país
#     skip_existing=True       # No re-descargar existentes
# )

# print(f"✅ Temporadas procesadas: {stats['exitosos']}")
# print(f"👤 Jugadores procesados: {stats['jugadores_exitosos']}")
# print(f"❌ Errores: {stats['fallos']}")

# ############################################################################################

# # 2. Opción inteligente (auto-reanudable):
# # Para auto-detectar desde dónde continuar
# from scraping_player_bio import smart_download_player_bio

# stats = smart_download_player_bio(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=False,  # Continuar desde donde se quedó
#     batch_size=10             # Solo 10 temporadas (cada una tiene MUCHOS jugadores)
# )

# print(f"🎯 Progreso: {stats['progress']['percentage']:.1f}%")

# ############################################################################################

# # 3. Para empezar de cero:
# # Borrar biografías existentes y empezar limpio
# stats = smart_download_player_bio(
#     df_seasons,
#     pais='Argentina',
#     restart_from_zero=True,   # 🔥 Borrar y empezar de cero
#     batch_size=5              # Muy pocas temporadas porque procesa MUCHOS jugadores
# )

# ############################################################################################

# # 4. Control granular por competición específica:
# # Solo Liga Profesional Argentina
# stats = download_player_bio_by_filters(
#     df_seasons,
#     competicion='Liga Profesional Argentina',
#     skip_existing=True,
#     limit=2  # Solo 2 temporadas para probar
# )

# ############################################################################################

# # 5. Procesamiento por lotes (recomendado):
# # Para procesar en lotes pequeños
# from scraping_player_bio import PlayerBioScraper

# scraper = PlayerBioScraper()

# # Configurar delays más largos (muchas peticiones por temporada)
# scraper.set_delay_range(2.0, 4.0)

# # Procesar solo algunas temporadas
# stats = scraper.process_seasons(
#     df_seasons,
#     filters={'pais': 'Argentina'},
#     start_index=0,
#     limit=3,  # Solo 3 temporadas (pueden ser cientos de jugadores)
#     skip_existing=True
# )

# %%
# En lugar de tu loop actual, usa esto:
from scraping_seasons import load_existing_seasons
from scraping_player_bio import download_player_bio_by_filters

# Cargar temporadas
# df_seasons = load_existing_seasons()

# Descargar biografías de jugadores (requiere squads.json)
stats = download_player_bio_by_filters(
    df_seasons,
    # pais='Argentina',        # Filtro por país
    # competicion='Liga Profesional Argentina',
    pais='FIFA',
    continente='World',
    skip_existing=True       # No re-descargar existentes
)
# Out:
# 🔍 Filtro aplicado - continente: World → 2 temporadas
# 🔍 Filtro aplicado - pais: FIFA → 2 temporadas
# 🚀 Iniciando descarga de biografías de jugadores...
#    - Temporadas originales: 2
#    - Temporadas después de filtros: 2
#    - Temporadas a procesar: 2
#    - Rango: 0 a 1
#    - Delay entre jugadores: 1.0-2.0 segundos
#    ⚠️  Requiere archivos squads.json previos
#    ⚠️  ADVERTENCIA: Muchas peticiones (puede ser lento)
#
# 📋 Procesando 1/2: FIFA U20 World Cup - 2025 Chile
# ✅ Extraídos 535 jugadores del archivo squads.json
# 👤 Procesando biografías para 535 jugadores...
#   📖 Descargando bio (1/535): Tomás Pérez Zambrana (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=1ygjcmalpc0pqj024dsha28lw&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Pérez Zambrana_Tomás_1ygjcmalpc0pqj024dsha28lw.json
#   📖 Descargando bio (2/535): Santino Barbi (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=2h190lj3g6gb1tq47fw4joljo&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Barbi_Santino_2h190lj3g6gb1tq47fw4joljo.json
#   📖 Descargando bio (3/535): Santino Andino Valencia (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=2s80bfibo84ucwkl36lkzqvpw&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Andino Valencia_Santino_2s80bfibo84ucwkl36lkzqvpw.json
#   📖 Descargando bio (4/535): Álvaro Busso (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=3lsasz0vofwkcecptg59n5xxw&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Busso_Álvaro_3lsasz0vofwkcecptg59n5xxw.json
#   📖 Descargando bio (5/535): Dylan Tomás Gorosito (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=3oc05t8rmsop85230fq5clzbo&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Gorosito_Dylan Tomás_3oc05t8rmsop85230fq5clzbo.json
#   📖 Descargando bio (6/535): Teo Rodríguez Pagano (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=3xajrwciw9lkpuzxo2ngz50r8&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Rodríguez Pagano_Teo_3xajrwciw9lkpuzxo2ngz50r8.json
#   📖 Descargando bio (7/535): Mateo Silvetti (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=5aayh9oesanoys37bbjod4m50&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Silvetti_Mateo_5aayh9oesanoys37bbjod4m50.json
#   📖 Descargando bio (8/535): Gianluca Prestianni Gross (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=6pavdf2072176dag5nt8qni8k&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Prestianni Gross_Gianluca_6pavdf2072176dag5nt8qni8k.json
#   📖 Descargando bio (9/535): Tobías Emanuel Ramírez Cardozo (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=8asxb7t766ih2491i2fyhma6s&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Ramírez Cardozo_Tobías Emanuel_8asxb7t766ih2491i2fyhma6s.json
#   📖 Descargando bio (10/535): Tobías Luciano Andrada (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=8t9ly6vd5fvvp5h6qob903dg&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Andrada_Tobías Luciano_8t9ly6vd5fvvp5h6qob903dg.json
#   📖 Descargando bio (11/535): Alain Gómez Santillán (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=9bypydqwref5m33t57hj9s9w4&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Gómez Santillán_Alain_9bypydqwref5m33t57hj9s9w4.json
#   📖 Descargando bio (12/535): Valente Pierani (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=9ejliidn5wpyfpgb26c6vims&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Pierani_Valente_9ejliidn5wpyfpgb26c6vims.json
#   📖 Descargando bio (13/535): Ian Martín Subiabre (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=a79sdaktnnq3feaor056hxlw4&_rt=c&_fmt=jsonp&_lcl=en-gb&_clbk=W3e14cbc3e4b2577e854bf210e5a3c7028c7409678
#   ✅ Guardado: Subiabre_Ian Martín_a79sdaktnnq3feaor056hxlw4.json
#   📖 Descargando bio (14/535): Diego Rodolfo Placente (Argentina U20)
# 👤 API URL: https://api.performfeeds.com/soccerdata/nlgdynamicplayerbio/ft1tiv1inq7v1sk3y9tv12yh5/?prsn=
#   ⏭️  Jugador ya existe (saltando): Nolhann Timothéo Clément Glenn Alebate
#   ⏭️  Jugador ya existe (saltando): Tamumue Emmanuel Gaston Ajapuhnya
#   ⏭️  Jugador ya existe (saltando): Pierre Watreng Wajoka
#   ⏭️  Jugador ya existe (saltando): Djoan Justin Emmanuel Lomani Nahiet
#   ⏭️  Jugador ya existe (saltando): Yazid-Enzo Hmaen Wajoka
#   ⏭️  Jugador ya existe (saltando): Wapae Antoine Rene Simane
#   ⏭️  Jugador ya existe (saltando): Kapone Emmanuel Lambert Xulue
#   ⏭️  Jugador ya existe (saltando): Noa Yohan Bernard Bochet Muller
#   ⏭️  Jugador ya existe (saltando): Louis David Jean-Jacques Brunet
#   ⏭️  Jugador ya existe (saltando): Evans Felicien Romain Vakie
#   ⏭️  Jugador ya existe (saltando): Jytrhim Natidjan Abel Doui Upa
#   ⏭️  Jugador ya existe (saltando): Emmanuel Wahnapo Jean Wahnapo
#   ⏭️  Jugador ya existe (saltando): Anthony Levy
#   ⏭️  Jugador ya existe (saltando): Timotei Joseph Tagihau Zeter
#   ⏭️  Jugador ya existe (saltando): Kandjo Andre Hubert Teanyouen
#   ⏭️  Jugador ya existe (saltando): Joseph Brynley Wallis
#   ⏭️  Jugador ya existe (saltando): Michael John Mayne
#   ⏭️  Jugador ya existe (saltando): James Andrew Bulkeley
#   ⏭️  Jugador ya existe (saltando): Adama Mahamadou Gemmell-Coulibaly
#   ⏭️  Jugador ya existe (saltando): Jayden James Smith
#   ⏭️  Jugador ya existe (saltando): Keegan James Kelly
#   ⏭️  Jugador ya existe (saltando): Stipe Josip Ukich
#   ⏭️  Jugador ya existe (saltando): Lukas Eric Kelly-Heald
#   ⏭️  Jugador ya existe (saltando): Tze-Xuan Loke
#   ⏭️  Jugador ya existe (saltando): Josey Brian Casa-Grande
#   ⏭️  Jugador ya existe (saltando): Luke Stuart Supyk
#   ⏭️  Jugador ya existe (saltando): Finn Hunter McKenlay
#   ⏭️  Jugador ya existe (saltando): Christopher Mark Greenacre
#   ⏭️  Jugador ya existe (saltando): Henry Merson Leonard Gray
#   ⏭️  Jugador ya existe (saltando): Codey John Kevin Phoenix
#   ⏭️  Jugador ya existe (saltando): Troy Steven Putt
#   ⏭️  Jugador ya existe (saltando): Oliver James Middleton
#   ⏭️  Jugador ya existe (saltando): Noah Charles Evenor Dupont
#   ⏭️  Jugador ya existe (saltando): Nathan Barry Walker
#   ⏭️  Jugador ya existe (saltando): Ryan Daniel Michael Watson
#   ⏭️  Jugador ya existe (saltando): Gabriel Edward Sloane-Rodrigues
#   ⏭️  Jugador ya existe (saltando): Neil Emblen
#   ⏭️  Jugador ya existe (saltando): Fergus William Gillion
#   ⏭️  Jugador ya existe (saltando): Luke Joseph Brooke-Smith
#   ⏭️  Jugador ya existe (saltando): Daniel Demenenge Daga
#   ⏭️  Jugador ya existe (saltando): Ahmed Olamide Akinyele
#   ⏭️  Jugador ya existe (saltando): Charles Adah Agada
#   ⏭️  Jugador ya existe (saltando): Odinaka Emmanuel Okoro
#   ⏭️  Jugador ya existe (saltando): Emmanuel Ekowoicho Ekele
#   ⏭️  Jugador ya existe (saltando): Israel Isaac Ayuma
#   ⏭️  Jugador ya existe (saltando): Orseer Achihi
#   ⏭️  Jugador ya existe (saltando): Daniel Kolocho Bameyi
#   ⏭️  Jugador ya existe (saltando): Azuka Alatan
#   ⏭️  Jugador ya existe (saltando): Rufai Abubakar
#   ⏭️  Jugador ya existe (saltando): Sani Abacha Suleiman
#   ⏭️  Jugador ya existe (saltando): Abdullahi Shitu Ele
#   ⏭️  Jugador ya existe (saltando): Kparobo Nathaniel Arierhi
#   ⏭️  Jugador ya existe (saltando): Clinton Andy Ezekiel
#   ⏭️  Jugador ya existe (saltando): Abduljelil Mustapha Kamaldeen
#   ⏭️  Jugador ya existe (saltando): Haruna Aliyu
#   ⏭️  Jugador ya existe (saltando): Tahir Maigana
#   ⏭️  Jugador ya existe (saltando): Ebenezer Ifeanyi Harcourt
#   ⏭️  Jugador ya existe (saltando): Aliyu Zubairu
#   ⏭️  Jugador ya existe (saltando): Amos Onyejefu Ochoche
#   ⏭️  Jugador ya existe (saltando): Salihu Nasiru
#   ⏭️  Jugador ya existe (saltando): Auwal Ibrahim
#   ⏭️  Jugador ya existe (saltando): Magnus Holte
#   ⏭️  Jugador ya existe (saltando): Martin Håheim-Elveseter
#   ⏭️  Jugador ya existe (saltando): Julian Lægreid
#   ⏭️  Jugador ya existe (saltando): Magnus Brøndbo
#   ⏭️  Jugador ya existe (saltando): Mathias Øren
#   ⏭️  Jugador ya existe (saltando): Tobias Saliou Séne Moi
#   ⏭️  Jugador ya existe (saltando): Bjørn Johansen
#   ⏭️  Jugador ya existe (saltando): Vetle Auklend
#   ⏭️  Jugador ya existe (saltando): Niklas Kemp Fuglestad
#   ⏭️  Jugador ya existe (saltando): Einar Bøe Fauskanger
#   ⏭️  Jugador ya existe (saltando): Markus Haaland
#   ⏭️  Jugador ya existe (saltando): Kasper Sætherbø
#   ⏭️  Jugador ya existe (saltando): Sondre Milian Granaas
#   ⏭️  Jugador ya existe (saltando): Håkon Røsten
#   ⏭️  Jugador ya existe (saltando): Sander Kaldråstøyl Østraat
#   ⏭️  Jugador ya existe (saltando): Rasmus Holten
#   ⏭️  Jugador ya existe (saltando): Jonathan Vonheim Norbye
#   ⏭️  Jugador ya existe (saltando): Bork Classønn Bang-Kittilsen
#   ⏭️  Jugador ya existe (saltando): Luca Høyland
#   ⏭️  Jugador ya existe (saltando): Ola Visted
#   ⏭️  Jugador ya existe (saltando): Lars Bjørnerud Remmem
#   ⏭️  Jugador ya existe (saltando): Gustav Kjølstad Nyheim
#   ⏭️  Jugador ya existe (saltando): Joseph Edward Jones Córdoba
#   ⏭️  Jugador ya existe (saltando): Luis Aníbal Villarreal González
#   ⏭️  Jugador ya existe (saltando): Anel Enrique Ryce Moreno
#   ⏭️  Jugador ya existe (saltando): Martín Wilhelm Krug
#   ⏭️  Jugador ya existe (saltando): Julio Dicaprio Rodríguez Barrios
#   ⏭️  Jugador ya existe (saltando): Javier Alexander Arboleda Martínez
#   ⏭️  Jugador ya existe (saltando): Ernesto Alonso Gómez Ballis
#   ⏭️  Jugador ya existe (saltando): Érick Manuel Díaz González
#   ⏭️  Jugador ya existe (saltando): Antony Eymar Herbert Forcheney
#   ⏭️  Jugador ya existe (saltando): Giovany Aymar Herbert Forcheney
#   ⏭️  Jugador ya existe (saltando): Cecilio Rolando Burgess Mason
#   ⏭️  Jugador ya existe (saltando): Ryan Danilo Gómez Forcinhey
#   ⏭️  Jugador ya existe (saltando): Kairo Taimir Walters Linares
#   ⏭️  Jugador ya existe (saltando): Kevin Emanuel Walder Méndez
#   ⏭️  Jugador ya existe (saltando): Gustavo Eloy Herrera Prescott
#   ⏭️  Jugador ya existe (saltando): Jorge Luis Dely Valdés
#   ⏭️  Jugador ya existe (saltando): Juan Carlos Hall Daniels
#   ⏭️  Jugador ya existe (saltando): Sean Luca Deane Fernandez
#   ⏭️  Jugador ya existe (saltando): Karlo Kurányi
#   ⏭️  Jugador ya existe (saltando): Ian Dwaneth Sahil Flores García
#   ⏭️  Jugador ya existe (saltando): Ariel Abdiel Arroyo Tugwell
#   ⏭️  Jugador ya existe (saltando): Rafael Antonio Mosquera Díaz
#   ⏭️  Jugador ya existe (saltando): Lucas Ariel Quintana Rodríguez
#   ⏭️  Jugador ya existe (saltando): Lucas Pablo Guiñazú Fernández
#   ⏭️  Jugador ya existe (saltando): Francisco Silverio Mongelos Hanson
#   ⏭️  Jugador ya existe (saltando): Líder David Cáceres Coronel
#   ⏭️  Jugador ya existe (saltando): Rodrigo Javier Villalba Benítez
#   ⏭️  Jugador ya existe (saltando): Tiago Isaías Caballero Fleytas
#   ⏭️  Jugador ya existe (saltando): Gabriel Aguayo Díaz
#   ⏭️  Jugador ya existe (saltando): César Eduardo Miño Amarilla
#   ⏭️  Jugador ya existe (saltando): Axel Balbuena Otazú
#   ⏭️  Jugador ya existe (saltando): Giovanni Emanuel Gómez Lezcano
#   ⏭️  Jugador ya existe (saltando): Facundo Ezequiel Insfrán Lirussi
#   ⏭️  Jugador ya existe (saltando): David Emanuel Fernández Fariña
#   ⏭️  Jugador ya existe (saltando): Alan Tobías Morinigo
#   ⏭️  Jugador ya existe (saltando): Gian Gadiel Jesús Paoli
#   ⏭️  Jugador ya existe (saltando): Enso David González Medina
#   ⏭️  Jugador ya existe (saltando): Fabrizio Baruja Alderete
#   ⏭️  Jugador ya existe (saltando): Osmar Giménez Bernal
#   ⏭️  Jugador ya existe (saltando): Antolín Alcáraz Viveros
#   ⏭️  Jugador ya existe (saltando): Víctor Amancio Rojas Marín
#   ⏭️  Jugador ya existe (saltando): Ezequiel Maximiliano Duarte
#   ⏭️  Jugador ya existe (saltando): Octavio Anibal Alfonso Dure
#   ⏭️  Jugador ya existe (saltando): Alexandro Maidana Mendieta
#   ⏭️  Jugador ya existe (saltando): Talal bin Abubakr bin Abdullah Haji
#   ⏭️  Jugador ya existe (saltando): Saud bin Mohammed bin Yahya Harun
#   ⏭️  Jugador ya existe (saltando): Mohammed bin Ali bin Mohammed Barnawi
#   ⏭️  Jugador ya existe (saltando): Rakan Khalid Al Ghamdi
#   ⏭️  Jugador ya existe (saltando): Abdul Rahman bin Ali bin Ahmed Al Safar Al Ghamdi
#   ⏭️  Jugador ya existe (saltando): Saleh bin Ali bin Mohammed Barnawi
#   ⏭️  Jugador ya existe (saltando): Nawaf bin Abdullah bin Mohammed Al Ghulaimish
#   ⏭️  Jugador ya existe (saltando): Saud bin Mahmoud bin Osama Al Tumbukti
#   ⏭️  Jugador ya existe (saltando): Mahmoud Essa Anbar Al Burayh
#   ⏭️  Jugador ya existe (saltando): Hamed bin Abdullah bin Mohammed Yousef
#   ⏭️  Jugador ya existe (saltando): Marco Alexandre de Souza Soares
#   ⏭️  Jugador ya existe (saltando): Farhah bin Ali bin Saeed Al Qahtah Al Shamrani
#   ⏭️  Jugador ya existe (saltando): Bassam bin Abdullah bin Ali Dahash Hazazi
#   ⏭️  Jugador ya existe (saltando): Ramez bin Zaid bin Ahmed Al Attar
#   ⏭️  Jugador ya existe (saltando): Thamer bin Fathi bin Mustafa Al Dakhil Al Khaibri
#   ⏭️  Jugador ya existe (saltando): Eyad Sidi Mohammed Houssa
#   ⏭️  Jugador ya existe (saltando): Saad bin Hussain bin Mohammed Haqawi
#   ⏭️  Jugador ya existe (saltando): Awad bin Muhsen bin Ali Aman
#   ⏭️  Jugador ya existe (saltando): Antonio Sergio Piernas Cárdenas
#   ⏭️  Jugador ya existe (saltando): Amar bin Hamed bin Mohammed Al Yuhaybi
#   ⏭️  Jugador ya existe (saltando): Abdullah Fahad Al Sahli
#   ⏭️  Jugador ya existe (saltando): Ziyad bin Abdullah bin Ali Al Abdali Al Ghamdi
#   ⏭️  Jugador ya existe (saltando): Abdulmalik bin Ghazzi bin Al Hamidi Al Marwani Al Harbi
#   ⏭️  Jugador ya existe (saltando): Luke Junio Baartman
#   ⏭️  Jugador ya existe (saltando): Sfiso Maxwell Timba
#   ⏭️  Jugador ya existe (saltando): Lazola Maku
#   ⏭️  Jugador ya existe (saltando): Kutlwano Letlhaku
#   ⏭️  Jugador ya existe (saltando): Patrick Mojalefa Junior Autata
#   ⏭️  Jugador ya existe (saltando): Mfundo Obrigado Joy Vilakazi
#   ⏭️  Jugador ya existe (saltando): Thato Majoro Sibiya
#   ⏭️  Jugador ya existe (saltando): Asekho Tiwani
#   ⏭️  Jugador ya existe (saltando): Kgoleng Ratisani
#   ⏭️  Jugador ya existe (saltando): Fletcher Hani Smythe-Lowe
#   ⏭️  Jugador ya existe (saltando): Takalani Mazhamba
#   ⏭️  Jugador ya existe (saltando): Xaniseka Raymond Mdaka
#   ⏭️  Jugador ya existe (saltando): Siviwe Magidigidi
#   ⏭️  Jugador ya existe (saltando): Shakeel April
#   ⏭️  Jugador ya existe (saltando): Tylon Christopher Smith
#   ⏭️  Jugador ya existe (saltando): Thabang Tumelo Mahlangu
#   ⏭️  Jugador ya existe (saltando): Siviwe Nkwali
#   ⏭️  Jugador ya existe (saltando): Jody Lee Ahshene
#   ⏭️  Jugador ya existe (saltando): Neo Duncan Rapoo
#   ⏭️  Jugador ya existe (saltando): Langelihle Phili
#   ⏭️  Jugador ya existe (saltando): Siyabonga Nicolas Mabena
#   ⏭️  Jugador ya existe (saltando): Gomolemo Leviy Kekana
#   ⏭️  Jugador ya existe (saltando): Rodrigo Mendoza Martinez Moya
#   ⏭️  Jugador ya existe (saltando): Raúl Jiménez Latorre
#   ⏭️  Jugador ya existe (saltando): Joel Roca Casals
#   ⏭️  Jugador ya existe (saltando): Francisco Javier González Pérez
#   ⏭️  Jugador ya existe (saltando): Jan Virgili Tenas
#   ⏭️  Jugador ya existe (saltando): Diego Aguado Facio
#   ⏭️  Jugador ya existe (saltando): David Mella Boullón
#   ⏭️  Jugador ya existe (saltando): Cristian David Perea Cajiao
#   ⏭️  Jugador ya existe (saltando): Izan Merino Rodríguez
#   ⏭️  Jugador ya existe (saltando): Pablo García Fernández
#   ⏭️  Jugador ya existe (saltando): Francisco Gallardo León
#   ⏭️  Jugador ya existe (saltando): Rayane Belaid Khellil
#   ⏭️  Jugador ya existe (saltando): Iker Bravo Solanilla
#   ⏭️  Jugador ya existe (saltando): Álvaro Cortés Moyano
#   ⏭️  Jugador ya existe (saltando): Jesús Fortea Tejedo
#   ⏭️  Jugador ya existe (saltando): Jon Martín Vicente
#   ⏭️  Jugador ya existe (saltando): Andrés Cuenca Cejudo
#   ⏭️  Jugador ya existe (saltando): Thiago Pitarch Pinar
#   ⏭️  Jugador ya existe (saltando): Julio Díaz del Romo
#   ⏭️  Jugador ya existe (saltando): Vicent Abril Sanz
#   ⏭️  Jugador ya existe (saltando): Pau Navarro Badenes
#   ⏭️  Jugador ya existe (saltando): Adrián Liso Lahoz
#   ⏭️  Jugador ya existe (saltando): Peio Canales Urtasun
#   ⏭️  Jugador ya existe (saltando): Kyrylo Dihtiar
#   ⏭️  Jugador ya existe (saltando): Daniil Vashchenko
#   ⏭️  Jugador ya existe (saltando): Oleksandr Pyshchur
#   ⏭️  Jugador ya existe (saltando): Vitalii Katrych
#   ⏭️  Jugador ya existe (saltando): Artur Shakh
#   ⏭️  Jugador ya existe (saltando): Mykola Kyrychok
#   ⏭️  Jugador ya existe (saltando): Hennadii Synchuk
#   ⏭️  Jugador ya existe (saltando): Bohdan Budko
#   ⏭️  Jugador ya existe (saltando): Dmytro Mykhailenko
#   ⏭️  Jugador ya existe (saltando): Maksym Derkach
#   ⏭️  Jugador ya existe (saltando): Kristian Michael Shevchenko
#   ⏭️  Jugador ya existe (saltando): Matvii Panchenko
#   ⏭️  Jugador ya existe (saltando): Vladyslav Krapyvtsov
#   ⏭️  Jugador ya existe (saltando): Yaroslav Karaman
#   ⏭️  Jugador ya existe (saltando): Matvii Ponomarenko
#   ⏭️  Jugador ya existe (saltando): Danylo Krevsun
#   ⏭️  Jugador ya existe (saltando): Vladyslav Kysil
#   ⏭️  Jugador ya existe (saltando): Sviatoslav Vanivskyi
#   ⏭️  Jugador ya existe (saltando): Daniel Onyebuchi Vernattus
#   ⏭️  Jugador ya existe (saltando): Maksym Melnychenko
#   ⏭️  Jugador ya existe (saltando): Markiian Bakus
#   ⏭️  Jugador ya existe (saltando): Oleksii Husiev
#   ⏭️  Jugador ya existe (saltando): Nolan Chandler Norris
#   ⏭️  Jugador ya existe (saltando): Adam James Beaudry
#   ⏭️  Jugador ya existe (saltando): Francis W. Westfield
#   ⏭️  Jugador ya existe (saltando): Marcos Alberto Zambrano Delgado
#   ⏭️  Jugador ya existe (saltando): William Cole Campbell
#   ⏭️  Jugador ya existe (saltando): Duran Michael Ferree
#   ⏭️  Jugador ya existe (saltando): Matthew James Corcoran
#   ⏭️  Jugador ya existe (saltando): Benjamín Cremaschi
#   ⏭️  Jugador ya existe (saltando): Joshua Liam Wynder
#   ⏭️  Jugador ya existe (saltando): Zavier Didier Tapei Gozo
#   ⏭️  Jugador ya existe (saltando): Brooklyn Sigel Randolph Raines
#   ⏭️  Jugador ya existe (saltando): Ethan David Kohler
#   ⏭️  Jugador ya existe (saltando): Reed Vanarthur Baker-Whiting
#   ⏭️  Jugador ya existe (saltando): Gavin Lee Beavers
#   ⏭️  Jugador ya existe (saltando): Marko Mitrović
#   ⏭️  Jugador ya existe (saltando): Peyton James Miller
#   ⏭️  Jugador ya existe (saltando): Diego Kochen
#   ⏭️  Jugador ya existe (saltando): Nikolas Diego Tsakiris
#   ⏭️  Jugador ya existe (saltando): Luke James Brennan
#   ⏭️  Jugador ya existe (saltando): Noah Franklin Cobb
#   ⏭️  Jugador ya existe (saltando): Pedro José Soma
#   ⏭️  Jugador ya existe (saltando): Taha Habroune
#   ⏭️  Jugador ya existe (saltando): Luca Dylan Bombino
# 👤 Temporada completada: 0 exitosos, 535 saltados, 0 fallidos
#
# 📊 Progreso: 2/2 temporadas (100.0%)
#    ⚡ Velocidad temporadas: 0.10/minuto
#    ⚡ Velocidad jugadores: 27.91/minuto
#    ✅ Temporadas exitosas: 1
#    👤 Jugadores procesados: 535
#    📈 Jugadores exitosos: 535
#    ❌ Errores: 1
#    ⏰ Tiempo estimado restante: 0.0 minutos
#
# ================================================================================
# 👤 RESUMEN FINAL - DESCARGA DE BIOGRAFÍAS DE JUGADORES
# ================================================================================
# ⏰ Tiempo total: 1150.2 segundos (19.2 minutos)
# 📋 Temporadas procesadas: 2/2
# ✅ Temporadas exitosas: 1
# ❌ Temporadas fallidas: 1
# 👤 Total jugadores procesados: 535
# 📈 Jugadores exitosos: 535
# ⏭️  Jugadores saltados: 535
# 💥 Jugadores fallidos: 0
# ⚡ Velocidad temporadas: 0.10/minuto
# ⚡ Velocidad jugadores: 27.91/minuto
# 📈 Tasa de éxito jugadores: 100.0%
# 📈 Tasa de éxito temporadas: 50.0%
# ⏱️  Tiempo estimado para 1000 jugadores: 35.8 minutos

# %%
print(f"✅ Temporadas procesadas: {stats['exitosos']}")
print(f"👤 Jugadores procesados: {stats['jugadores_exitosos']}")
print(f"❌ Errores: {stats['fallos']}")
